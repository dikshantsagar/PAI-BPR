# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install -q torch==1.0.0 torchvision==0.2.1

# %% [markdown]
# Enter the path of the parent directory of Group_9 folder just before "/Group_9/src/train.py"

# %%
# !python 'Enter the path of parent directory of Group_9 folder/Group_9/src/test.py'

# %%
###!python '/content/drive/My Drive/GPBPR/Group_9/src/test.py'
# Out:
# loading visual features
# successful
# loading model
# successful
# Test Score:  0.8502320458973804
